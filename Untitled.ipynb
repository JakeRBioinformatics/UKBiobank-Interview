# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from typing import Dict, List
import csv
import os
import uvicorn
import nest_asyncio
from threading import Thread

# ---------- CONFIG ----------
CSV_FILE = "patients.csv"

# ---------- DATA MODEL ----------
class Patient(BaseModel):
    patient_id: str
    age: int
    sex: str
    BMI: float
    diagnosis_code: str
    sample_taken: bool
    blood_pressure: str
    cholesterol_level: float

# ---------- CSV FUNCTIONS ----------
def load_patients_from_csv() -> Dict[str, Patient]:
    if not os.path.exists(CSV_FILE):
        return {}
    with open(CSV_FILE, newline='') as f:
        reader = csv.DictReader(f)
        data = {}
        for row in reader:
            row['age'] = int(row['age'])
            row['BMI'] = float(row['BMI'])
            row['sample_taken'] = row['sample_taken'].lower() == "true"
            row['cholesterol_level'] = float(row['cholesterol_level'])
            data[row['patient_id']] = Patient(**row)
        return data

def save_patients_to_csv():
    with open(CSV_FILE, mode='w', newline='', encoding='utf-8') as f:
        fieldnames = list(Patient.__fields__)  # Pydantic v1 compatibility
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for patient in patients.values():
            writer.writerow(patient.dict())
        print("Saving to:", os.path.abspath(CSV_FILE))

# ---------- APP INITIALIZATION ----------
app = FastAPI()
patients: Dict[str, Patient] = load_patients_from_csv()

# ---------- API ROUTES ----------
@app.get("/patients", response_model=List[Patient])
def get_all_patients():
    return list(patients.values())

@app.get("/patients/{patient_id}", response_model=Patient)
def get_patient(patient_id: str):
    if patient_id not in patients:
        raise HTTPException(status_code=404, detail="Patient not found")
    return patients[patient_id]

@app.post("/patients", response_model=Patient, status_code=201)
def create_patient(patient: Patient):
    if patient.patient_id in patients:
        raise HTTPException(status_code=400, detail="Patient already exists")
    patients[patient.patient_id] = patient
    save_patients_to_csv()
    return patient

@app.put("/patients/{patient_id}", response_model=Patient)
def update_patient(patient_id: str, updated: Patient):
    if patient_id not in patients:
        raise HTTPException(status_code=404, detail="Patient not found")
    patients[patient_id] = updated
    save_patients_to_csv()
    return updated

@app.delete("/patients/{patient_id}", status_code=204)
def delete_patient(patient_id: str):
    if patient_id not in patients:
        raise HTTPException(status_code=404, detail="Patient not found")
    del patients[patient_id]
    save_patients_to_csv()

# ---------- SERVER LAUNCH ----------
nest_asyncio.apply()

def run():
    uvicorn.run(app, host="127.0.0.1", port=8000)

Thread(target=run, daemon=True).start()

# %%
patients
# Out:
# {'PAT1000': Patient(patient_id='PAT1000', age=67, sex='Female', BMI=17.0, diagnosis_code='I75', sample_taken=False, blood_pressure='141/79', cholesterol_level=7.8),
#  'PAT1001': Patient(patient_id='PAT1001', age=63, sex='Female', BMI=37.4, diagnosis_code='I37', sample_taken=True, blood_pressure='126/68', cholesterol_level=6.8),
#  'PAT1002': Patient(patient_id='PAT1002', age=50, sex='Male', BMI=39.6, diagnosis_code='I87', sample_taken=True, blood_pressure='129/66', cholesterol_level=6.6),
#  'PAT1003': Patient(patient_id='PAT1003', age=61, sex='Female', BMI=29.4, diagnosis_code='I55', sample_taken=False, blood_pressure='130/99', cholesterol_level=6.2),
#  'PAT1004': Patient(patient_id='PAT1004', age=44, sex='Female', BMI=27.4, diagnosis_code='I76', sample_taken=False, blood_pressure='97/95', cholesterol_level=7.6),
#  'PAT1005': Patient(patient_id='PAT1005', age=48, sex='Male', BMI=36.2, diagnosis_code='I95', sample_taken=True, blood_pressure='153/81', cholesterol_level=4.2),
#  'PAT1006': Patient(patient_id='PAT1006', age=59, sex='Female', BMI=36.9, diagnosis_code='I34', sample_taken=True, blood_pressure='120/69', cholesterol_level=7.0),
#  'PAT1008': Patient(patient_id='PAT1008', age=61, sex='Male', BMI=24.0, diagnosis_code='I79', sample_taken=True, blood_pressure='160/97', cholesterol_level=4.4),
#  'PAT1009': Patient(patient_id='PAT1009', age=45, sex='Male', BMI=35.2, diagnosis_code='I50', sample_taken=True, blood_pressure='127/71', cholesterol_level=3.9)}
# INFO:     127.0.0.1:62739 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62737 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62740 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62736 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62738 - "GET /struts2-showcase/struts/utils.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62760 - "GET /js/?${jndi:dns://MDEDiscovery2f15158569SeenInTheWildGet-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62781 - "GET /struts2-showcase/struts/tooltip.gif HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62780 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62784 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62783 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62782 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62785 - "GET /struts2-showcase/struts/domtt.css HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62786 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62787 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62788 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62789 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62790 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62791 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62792 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62793 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62794 - "GET /struts2-showcase/struts/domTT.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62795 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62796 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62800 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62797 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62798 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62799 - "GET /struts2-showcase/struts/inputtransfersselect.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62801 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62802 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62803 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62804 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62806 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62805 - "GET /struts2-showcase/struts/optiontransferselect.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62807 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62809 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62808 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62812 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62810 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62811 - "GET /struts2-showcase HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62813 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62815 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62817 - "GET /index.action/struts/utils.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62814 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62816 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62818 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62819 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62820 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62821 - "POST /struts2-showcase/token/transfer4.action HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62822 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62823 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62824 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62825 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62826 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62827 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62828 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62830 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62829 - "GET /struts2-showcase/%24%7Bjndi%3Adns%3A//MDEDiscovery2f15158569ApacheStruts2-8000%7D HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62833 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62831 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62832 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62835 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62834 - "POST /struts2-showcase/token/transfer4.action HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62836 - "POST /analytics/telemetry/ph/api/hyper/send?_c=${jndi:dns://MDEDiscovery2f15158569VMwarevCenter-8000}&i=test HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62838 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62837 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62839 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62840 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62843 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62842 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62844 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62845 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62846 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62847 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62848 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62849 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62850 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62851 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62852 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62853 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62854 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62855 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62856 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62857 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62858 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62860 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62859 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62861 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62862 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62863 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62865 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62864 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62866 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62867 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62868 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62869 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62871 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62870 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62872 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62873 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62874 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62875 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62876 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62877 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62878 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62880 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62879 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62882 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62881 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62883 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62884 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62885 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62886 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62887 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62888 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62889 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62890 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62891 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62892 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62893 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62895 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62898 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62896 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62897 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62899 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62900 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62901 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62902 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62903 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     ${jndi:dns://MDEDiscovery2f15158569X-Forwarded-For-8000}:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62905 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62908 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62907 - "GET / HTTP/1.1" 404 Not Found
# INFO:     ${jndi:dns://MDEDiscovery2f15158569X-Forwarded-For-8000}:0 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62911 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62910 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62909 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62912 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62913 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62914 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62915 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62916 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62917 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62918 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62919 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62920 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62921 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62922 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62923 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62924 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62925 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62926 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62927 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62928 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62929 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62930 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62931 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62933 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62932 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62934 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62935 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62937 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62936 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62938 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62939 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62940 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62943 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62941 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62942 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62944 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62946 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62945 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62947 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62948 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62949 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62950 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62951 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62952 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62953 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62954 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62955 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62957 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62956 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62958 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62960 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62959 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62961 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62962 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62964 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62965 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62966 - "GET /JSPWiki/wiki/%24%7Bjndi%3Adns%3A//MDEDiscovery2f15158569ApacheJspWiki-8000%7D HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62967 - "GET /webtools/control/main HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62968 - "POST /broker/xml HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62969 - "POST /broker/xml HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62970 - "GET /portal/info.jsp HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62972 - "GET /api/v2/%24%7Bjndi%3Adns%3A//MDEDiscovery2f15158569SeenInTheWildGet-8000%7D HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62973 - "GET /api/?${jndi:dns://MDEDiscovery2f15158569SeenInTheWildGet-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62974 - "GET /index.html?${jndi:dns://MDEDiscovery2f15158569SeenInTheWildGet-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62975 - "GET /login HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62976 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62977 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62978 - "POST / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62979 - "POST /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62980 - "POST /login HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62981 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62982 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62983 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62984 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62985 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62986 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62987 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62988 - "GET /cgi-bin/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62989 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62990 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62991 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62992 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62993 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62994 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62995 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62996 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62997 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62998 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:62999 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63000 - "GET /%3Aundefined HTTP/1.1" 404 Not Found
# WARNING:  Invalid HTTP request received.
# WARNING:  Invalid HTTP request received.
# INFO:     127.0.0.1:63003 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63004 - "GET /cgi-bin/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63007 - "GET /?x=${jndi:dns://MDEDiscovery2f15158569xParam-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63008 - "POST /?v=${jndi:dns://MDEDiscovery2f15158569vPostParam-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63009 - "POST /?param=${jndi:dns://MDEDiscovery2f15158569ParamUriParam-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63010 - "GET /?v=${jndi:dns://MDEDiscovery2f15158569vGetParam-8000} HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63011 - "POST / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63012 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63048 - "GET /patients HTTP/1.1" 200 OK
# Saving to: C:\Users\mfbx2jrj\UKBiobank-Interview\patients.csv
# INFO:     127.0.0.1:63059 - "PUT /patients/PAT1000 HTTP/1.1" 200 OK
# Saving to: C:\Users\mfbx2jrj\UKBiobank-Interview\patients.csv
# INFO:     127.0.0.1:63075 - "PUT /patients/PAT1000 HTTP/1.1" 200 OK
